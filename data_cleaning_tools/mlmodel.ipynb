# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
import joblib as jb

# %%
import pandas as pd
df=pd.read_csv(r"/Users/yuganshsuri/Desktop/disease prediction/data/clean.csv")

# %%
df.drop(["Unnamed: 0"],axis=1,inplace=True)

# %%
x=df.drop(["Disease"],axis=1)#independt
y=df["Disease"]#dependent

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.3)

# %%
lr=LogisticRegression()#logistic regression
lr.fit(x_train,y_train)
lr.score(x_train,y_train)
lr.score(x_test,y_test)
jb.dump(lr,"linear_regression.lb")

# %%
sv=SVC()#svm
sv.fit(x_train,y_train)
sv.score(x_train,y_train)
sv.score(x_test,y_test)
jb.dump(sv,"svm.lb")

# %%
dt=DecisionTreeClassifier()#decision tree
dt.fit(x_train,y_train)
dt.score(x_train,y_train)
dt.score(x_test,y_test)
jb.dump(dt,"decision_tree.lb")

# %%
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
jb.dump(rf,"random_forest_model.lb")

# %%
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
jb.dump(knn,"knn_model.lb")

# %%
df.head()

# %%
df["Disease"].unique()

# %%
model=jb.load(r"/Users/yuganshsuri/Desktop/disease prediction/model/random_forest_model.lb")
model.score(x_train,y_train)
# Out:
# 1.0

# %%
model.score(x_test,y_test)
# Out:
# 0.776

# %%
x_test.head()
# Out:
#       Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 6252   36       0  23.5            122           156          146         99
# 4684   52       1  23.0            147           137          273        107
# 1731   78       0  26.3            118           128          125         55
# 4742   46       0  22.6            161           211          147         59
# 4521   64       1  27.2            126           261          162        108
#
#       Smoking  Alcohol  PhysicalActivity  FamilyHistory
# 6252        0        1                 0              1
# 4684        0        0                 1              0
# 1731        0        0                 0              1
# 4742        0        0                 2              0
# 4521        1        1                 0              0
