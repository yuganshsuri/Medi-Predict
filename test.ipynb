# %%
import joblib as jb

# %%
from data_cleaning_tools.mlmodel import y_train
from data_cleaning_tools.mlmodel import x_train
model=jb.load(r"/Users/yuganshsuri/Desktop/disease prediction/model/random_forest_model.lb")
model.score(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from data_cleaning_tools.mlmodel import y_train
#       2 from data_cleaning_tools.mlmodel import x_train
#       3 model=jb.load(r"/Users/yuganshsuri/Desktop/disease prediction/model/random_forest_model.lb")
#       4 model.score(x_train,y_train)
#
# ModuleNotFoundError: No module named 'data_cleaning_tools.mlmodel'
